# %% [markdown]
# # Twin-Delayed DDPG

# %% [markdown]
# ## Importing the libraries

# %%
import os
import time
import random
import numpy as np
import matplotlib.pyplot as plt
import pybullet_envs
import gym
import torch
import torch.nn as nn
import torch.nn.functional as F
from gym import wrappers
import mujoco_py
# Out:
# running build_ext

# %% [markdown]
# ## Initialize the Experience Replay memory

# %%
class ReplayBuffer(object):

  def __init__(self, max_size=1e6):
    self.storage = []
    self.max_size = max_size
    self.ptr = 0

  def add(self, transition):
    if len(self.storage) == self.max_size:
      self.storage[int(self.ptr)] = transition
      self.ptr = (self.ptr + 1) % self.max_size
    else:
      self.storage.append(transition)

  def sample(self, batch_size):
    ind = np.random.randint(0, len(self.storage), size=batch_size)
    batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = [], [], [], [], []
    for i in ind: 
      state, next_state, action, reward, done = self.storage[i]
      batch_states.append(np.array(state, copy=False))
      batch_next_states.append(np.array(next_state, copy=False))
      batch_actions.append(np.array(action, copy=False))
      batch_rewards.append(np.array(reward, copy=False))
      batch_dones.append(np.array(done, copy=False))
    return np.array(batch_states), np.array(batch_next_states), np.array(batch_actions), np.array(batch_rewards).reshape(-1, 1), np.array(batch_dones).reshape(-1, 1)

# %% [markdown]
# ## Build one neural network for the Actor model and one neural network for the Actor target

# %%
class Actor(nn.Module):
  
  def __init__(self, state_dim, action_dim, max_action):
    super(Actor, self).__init__()
    self.layer_1 = nn.Linear(state_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, action_dim)
    self.max_action = max_action

  def forward(self, x):
    x = F.relu(self.layer_1(x))
    x = F.relu(self.layer_2(x))
    x = self.max_action * torch.tanh(self.layer_3(x))
    return x

# %% [markdown]
# ## Build two neural networks for the two Critic models and two neural networks for the two Critic targets

# %%
class Critic(nn.Module):
  
  def __init__(self, state_dim, action_dim):
    super(Critic, self).__init__()
    # Defining the first Critic neural network
    self.layer_1 = nn.Linear(state_dim + action_dim, 400)
    self.layer_2 = nn.Linear(400, 300)
    self.layer_3 = nn.Linear(300, 1)
    # Defining the second Critic neural network
    self.layer_4 = nn.Linear(state_dim + action_dim, 400)
    self.layer_5 = nn.Linear(400, 300)
    self.layer_6 = nn.Linear(300, 1)

  def forward(self, x, u):
    xu = torch.cat([x, u], 1)
    
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    
    x2 = F.relu(self.layer_4(xu))
    x2 = F.relu(self.layer_5(x2))
    x2 = self.layer_6(x2)

    return x1, x2

  def Q1(self, x, u):
    xu = torch.cat([x, u], 1)
    x1 = F.relu(self.layer_1(xu))
    x1 = F.relu(self.layer_2(x1))
    x1 = self.layer_3(x1)
    return x1

# %% [markdown]
# ## Training Process

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class TD3(object):
  
  def __init__(self, state_dim, action_dim, max_action):
    self.actor = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target = Actor(state_dim, action_dim, max_action).to(device)
    self.actor_target.load_state_dict(self.actor.state_dict())
    self.actor_optimizer = torch.optim.Adam(self.actor.parameters())

    self.critic = Critic(state_dim, action_dim).to(device)
    self.critic_target = Critic(state_dim, action_dim).to(device)
    self.critic_target.load_state_dict(self.critic.state_dict())
    self.critic_optimizer = torch.optim.Adam(self.critic.parameters())

    self.max_action = max_action

  def select_action(self, state):
    state = torch.Tensor(state.reshape(1, -1)).to(device)
    return self.actor(state).cpu().data.numpy().flatten()

  def train(self, replay_buffer, iterations, batch_size=100, discount=0.99, tau=0.005, policy_noise=0.2, noise_clip=0.5, policy_freq=2):
    
    for it in range(iterations):
      
      batch_states, batch_next_states, batch_actions, batch_rewards, batch_dones = replay_buffer.sample(batch_size)
      state = torch.Tensor(batch_states).to(device)
      next_state = torch.Tensor(batch_next_states).to(device)
      action = torch.Tensor(batch_actions).to(device)
      reward = torch.Tensor(batch_rewards).to(device)
      done = torch.Tensor(batch_dones).to(device)
      
      next_action = self.actor_target(next_state)
      noise = torch.Tensor(batch_actions).data.normal_(0, policy_noise).to(device)
      noise = noise.clamp(-noise_clip, noise_clip)
      next_action = (next_action + noise).clamp(-self.max_action, self.max_action)
      
      target_Q1, target_Q2 = self.critic_target(next_state, next_action)
      target_Q = torch.min(target_Q1, target_Q2)
      target_Q = reward + ((1 - done) * discount * target_Q).detach()
      
      current_Q1, current_Q2 = self.critic(state, action)
      critic_loss = F.mse_loss(current_Q1, target_Q) + F.mse_loss(current_Q2, target_Q)
      
      self.critic_optimizer.zero_grad()
      critic_loss.backward()
      self.critic_optimizer.step()
      
      if it % policy_freq == 0:
        actor_loss = -self.critic.Q1(state, self.actor(state)).mean()
        self.actor_optimizer.zero_grad()
        actor_loss.backward()
        self.actor_optimizer.step()
        
        for param, target_param in zip(self.actor.parameters(), self.actor_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
        
        for param, target_param in zip(self.critic.parameters(), self.critic_target.parameters()):
          target_param.data.copy_(tau * param.data + (1 - tau) * target_param.data)
  
  def save(self, filename, directory):
    torch.save(self.actor.state_dict(), '%s/%s_actor.pth' % (directory, filename))
    torch.save(self.critic.state_dict(), '%s/%s_critic.pth' % (directory, filename))
  
  def load(self, filename, directory):
    self.actor.load_state_dict(torch.load('%s/%s_actor.pth' % (directory, filename)))
    self.critic.load_state_dict(torch.load('%s/%s_critic.pth' % (directory, filename)))

# %% [markdown]
# ## Make a function that evaluates the policy by calculating its average reward over 10 episodes

# %%
def evaluate_policy(policy, eval_episodes=10, isRender=False):
  avg_reward = 0.
  for i in range(eval_episodes):
    obs = env.reset()
    done = False
    while not done:
      if i + 1 == eval_episodes and isRender:
        env.render()

      action = policy.select_action(np.array(obs))
      obs, reward, done, _ = env.step(action)
      avg_reward += reward
    
    if isRender:
      env.close()
      env.reset()

  avg_reward /= eval_episodes
  print ("---------------------------------------")
  print ("Average Reward over the Evaluation Step: %f" % (avg_reward))
  print ("---------------------------------------")
  return avg_reward

# %% [markdown]
# ## Set the parameters

# %%
env_name = "Ant-v2"
seed = 0
start_timesteps = 1e4
eval_freq = 5e3
max_timesteps = 1e6
save_models = True
expl_noise = 0.1
batch_size = 100
discount = 0.99 
tau = 0.005
policy_noise = 0.2
noise_clip = 0.5
policy_freq = 2

# %% [markdown]
# ## Create a file name for the two saved models: the Actor and Critic models

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")
# Out:
# ---------------------------------------
# Settings: TD3_Ant-v2_0
# ---------------------------------------

# %% [markdown]
# ## Create a folder inside which will be saved the trained models

# %%
if not os.path.exists("./results"):
  os.makedirs("./results")
  
if save_models and not os.path.exists("./pytorch_models"):
  os.makedirs("./pytorch_models")

# %% [markdown]
# ## Create the PyBullet environment

# %%
env = gym.make(env_name)

# %% [markdown]
# ## Set seeds and we get the necessary information on the states and actions in the chosen environment

# %%
env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)
state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

# %% [markdown]
# ## Create the policy network and replay buffer

# %%
# Policy network:
policy = TD3(state_dim, action_dim, max_action)

# Replay buffer
replay_buffer = ReplayBuffer()

# %% [markdown]
# ## Define a list where all the evaluation results over 10 episodes are stored

# %%
evaluations = [evaluate_policy(policy, 2, True)]
# Out:
# Creating window glfw
# ---------------------------------------
# Average Reward over the Evaluation Step: 985.153252
# ---------------------------------------

# %% [markdown]
# ## Create a new folder directory in which the final results (videos of the agent) will be populated

# %%
def mkdir(base, name):
    path = os.path.join(base, name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

work_dir = mkdir('exp', 'brs')
monitor_dir = mkdir(work_dir, 'monitor')
max_episode_steps = env._max_episode_steps

# %% [markdown]
# ## Training

# %%
total_timesteps = 0
timesteps_since_eval = 0
episode_num = 0
done = True
t0 = time.time()

while total_timesteps < max_timesteps:
  
  # If the episode is done
  if done:
    if total_timesteps != 0:
      print("Total Timesteps: {} Episode Num: {} Reward: {}".format(total_timesteps, episode_num, episode_reward))
      policy.train(replay_buffer, episode_timesteps, batch_size, discount, tau, policy_noise, noise_clip, policy_freq)

    if timesteps_since_eval >= eval_freq:
      timesteps_since_eval %= eval_freq
      evaluations.append(evaluate_policy(policy))
      policy.save(file_name, directory="./pytorch_models")
      np.save("./results/%s" % (file_name), evaluations)
    
    obs = env.reset()
    done = False
    episode_reward = 0
    episode_timesteps = 0
    episode_num += 1
  
  # Before 10000 timesteps, we play random actions
  if total_timesteps < start_timesteps:
    action = env.action_space.sample()
  else:
    action = policy.select_action(np.array(obs))
    if expl_noise != 0:
      action = (action + np.random.normal(0, expl_noise, size=env.action_space.shape[0])).clip(env.action_space.low, env.action_space.high)
  
  new_obs, reward, done, _ = env.step(action)

  done_bool = 0 if episode_timesteps + 1 == env._max_episode_steps else float(done)
  episode_reward += reward
  replay_buffer.add((obs, new_obs, action, reward, done_bool))

  obs = new_obs
  episode_timesteps += 1
  total_timesteps += 1
  timesteps_since_eval += 1

# Add the last policy evaluation to our list of evaluations and we save our model
evaluations.append(evaluate_policy(policy))
if save_models: policy.save("%s" % (file_name), directory="./pytorch_models")
np.save("./results/%s" % (file_name), evaluations)
# Out:
# Total Timesteps: 157 Episode Num: 1 Reward: -143.54351621097098
# Total Timesteps: 236 Episode Num: 2 Reward: -55.316183680573666
# Total Timesteps: 1236 Episode Num: 3 Reward: -339.29842315590344
# Total Timesteps: 1504 Episode Num: 4 Reward: -97.77895997431226
# Total Timesteps: 2504 Episode Num: 5 Reward: -399.7608979445045
# Total Timesteps: 2559 Episode Num: 6 Reward: -31.109622138509856
# Total Timesteps: 2595 Episode Num: 7 Reward: -8.118218120428118
# Total Timesteps: 2631 Episode Num: 8 Reward: -2.60210228747282
# Total Timesteps: 3631 Episode Num: 9 Reward: -323.2135853339898
# Total Timesteps: 3656 Episode Num: 10 Reward: -0.8087687788968088
# Total Timesteps: 3764 Episode Num: 11 Reward: -24.059611080985537
# Total Timesteps: 3881 Episode Num: 12 Reward: -88.70078300295349
# Total Timesteps: 4881 Episode Num: 13 Reward: -359.119997335086
# Total Timesteps: 4909 Episode Num: 14 Reward: -26.255804837668922
# Total Timesteps: 4948 Episode Num: 15 Reward: -42.701436977400284
# ---------------------------------------
# Total Timesteps: 881772 Episode Num: 1246 Reward: 5141.708027841668
# Total Timesteps: 882772 Episode Num: 1247 Reward: 4848.8240261393275
# Total Timesteps: 883772 Episode Num: 1248 Reward: 5210.911968905213
# Total Timesteps: 884414 Episode Num: 1249 Reward: 3248.200676365437
# Total Timesteps: 885414 Episode Num: 1250 Reward: 5020.682371493383
# ---------------------------------------
# Average Reward over the Evaluation Step: 5395.404394
# ---------------------------------------
# Total Timesteps: 886414 Episode Num: 1251 Reward: 5071.873744188564
# Total Timesteps: 887414 Episode Num: 1252 Reward: 4782.898270647023
# Total Timesteps: 888414 Episode Num: 1253 Reward: 5332.832727301224
# Total Timesteps: 889414 Episode Num: 1254 Reward: 5186.657251012855
# Total Timesteps: 890097 Episode Num: 1255 Reward: 3688.520485097864
# ---------------------------------------
# Average Reward over the Evaluation Step: 5527.643750
# ---------------------------------------
# Total Timesteps: 891097 Episode Num: 1256 Reward: 5296.101062038397
# Total Timesteps: 892097 Episode Num: 1257 Reward: 5197.125704401519
# Total Timesteps: 893097 Episode Num: 1258 Reward: 5309.125477108629
# Total Timesteps: 894097 Episode Num: 1259 Reward: 5016.008943131848
# Total Timesteps: 895097 Episode Num: 1260 Reward: 5054.189075495846
# ---------------------------------------
# Average Reward over the Evaluation Step: 5087.767397
# ---------------------------------------
# Total Timesteps: 895163 Episode Num: 1261 Reward: 178.20017312482463
# Total Timesteps: 896163 Episode Num: 1262 Reward: 5338.040878368219
# Total Timesteps: 896382 Episode Num: 1263 Reward: 1100.4082162094548
# Total Timesteps: 897382 Episode Num: 1264 Reward: 5192.60154185779
# Total Timesteps: 898048 Episode Num: 1265 Reward: 3287.563796331413
# Total Timesteps: 898165 Episode Num: 1266 Reward: 480.6585573140914
# Total Timesteps: 899165 Episode Num: 1267 Reward: 5055.850663368718
# Total Timesteps: 900165 Episode Num: 1268 Reward: 4923.6935688161675
# ---------------------------------------
# Average Reward over the Evaluation Step: 4955.962834
# ---------------------------------------
# Total Timesteps: 901165 Episode Num: 1269 Reward: 5047.899444964699
# Total Timesteps: 902165 Episode Num: 1270 Reward: 5010.8088126770745
# Total Timesteps: 903165 Episode Num: 1271 Reward: 5158.98696254704
# Total Timesteps: 903536 Episode Num: 1272 Reward: 1704.7010508061705
# Total Timesteps: 904082 Episode Num: 1273 Reward: 2643.2417601143634
# Total Timesteps: 905082 Episode Num: 1274 Reward: 5067.700125695616
# ---------------------------------------
# Average Reward over the Evaluation Step: 4558.328075
# ---------------------------------------
# Total Timesteps: 906082 Episode Num: 1275 Reward: 5059.959133289025
# Total Timesteps: 907082 Episode Num: 1276 Reward: 5336.989598994758
# Total Timesteps: 908082 Episode Num: 1277 Reward: 5209.315955106029
# Total Timesteps: 909082 Episode Num: 1278 Reward: 5408.742692860023
# Total Timesteps: 910082 Episode Num: 1279 Reward: 5188.537181165053
# ---------------------------------------
# Average Reward over the Evaluation Step: 5458.079590
# ---------------------------------------
# Total Timesteps: 911082 Episode Num: 1280 Reward: 5163.376109412234
# Average Reward over the Evaluation Step: 5538.998301
# ---------------------------------------
# Total Timesteps: 976434 Episode Num: 1352 Reward: 5219.986429535402
# Total Timesteps: 977434 Episode Num: 1353 Reward: 5049.019769099897
# Total Timesteps: 977758 Episode Num: 1354 Reward: 1524.8915616615172
# Total Timesteps: 978046 Episode Num: 1355 Reward: 1317.130356534508
# Total Timesteps: 979046 Episode Num: 1356 Reward: 5415.763917953131
# Total Timesteps: 980046 Episode Num: 1357 Reward: 5029.030933729773
# ---------------------------------------
# Average Reward over the Evaluation Step: 4886.449700
# ---------------------------------------
# Total Timesteps: 981046 Episode Num: 1358 Reward: 4997.690804035434
# Total Timesteps: 981755 Episode Num: 1359 Reward: 3603.9557488242367
# Total Timesteps: 982159 Episode Num: 1360 Reward: 1871.6076748118667
# Total Timesteps: 983159 Episode Num: 1361 Reward: 5162.73628188456
# Total Timesteps: 984159 Episode Num: 1362 Reward: 5039.853738290478
# Total Timesteps: 985159 Episode Num: 1363 Reward: 4958.4551875791585
# ---------------------------------------
# Average Reward over the Evaluation Step: 4733.726924
# ---------------------------------------
# Total Timesteps: 986159 Episode Num: 1364 Reward: 5152.8023033903355
# Total Timesteps: 987159 Episode Num: 1365 Reward: 5028.4416190282445
# Total Timesteps: 988159 Episode Num: 1366 Reward: 5104.633952047465
# Total Timesteps: 989159 Episode Num: 1367 Reward: 4875.85636279026
# Total Timesteps: 990159 Episode Num: 1368 Reward: 5110.594231404758
# ---------------------------------------
# Average Reward over the Evaluation Step: 3880.637049
# ---------------------------------------
# Total Timesteps: 991159 Episode Num: 1369 Reward: 4813.323227539886
# Total Timesteps: 991478 Episode Num: 1370 Reward: 1559.00732310961
# Total Timesteps: 992478 Episode Num: 1371 Reward: 5583.465521074555
# Total Timesteps: 993478 Episode Num: 1372 Reward: 5030.784214237551
# Total Timesteps: 994478 Episode Num: 1373 Reward: 5235.597585755812
# Total Timesteps: 995478 Episode Num: 1374 Reward: 5030.366614262241
# ---------------------------------------
# Average Reward over the Evaluation Step: 4715.011039
# ---------------------------------------
# Total Timesteps: 996478 Episode Num: 1375 Reward: 5279.451010036752
# Total Timesteps: 997478 Episode Num: 1376 Reward: 5054.191698088161
# Total Timesteps: 998478 Episode Num: 1377 Reward: 5071.0161976717645
# Total Timesteps: 999478 Episode Num: 1378 Reward: 4788.943568816254
# ---------------------------------------
# Average Reward over the Evaluation Step: 5491.594655
# ---------------------------------------

# %% [markdown]
# ## Inference

# %%
file_name = "%s_%s_%s" % ("TD3", env_name, str(seed))
print ("---------------------------------------")
print ("Settings: %s" % (file_name))
print ("---------------------------------------")

eval_episodes = 10
isRender = True
env = gym.make(env_name)
max_episode_steps = env._max_episode_steps
env.reset()

env.seed(seed)
torch.manual_seed(seed)
np.random.seed(seed)

state_dim = env.observation_space.shape[0]
action_dim = env.action_space.shape[0]
max_action = float(env.action_space.high[0])

policy = TD3(state_dim, action_dim, max_action)
policy.load(file_name, './pytorch_models/')
_ = evaluate_policy(policy, eval_episodes=eval_episodes, isRender=isRender)
# Out:
# ---------------------------------------
# Settings: TD3_Ant-v2_0
# ---------------------------------------
# Creating window glfw
# ---------------------------------------
# Average Reward over the Evaluation Step: 5298.986548
# ---------------------------------------
